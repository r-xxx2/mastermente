# %%
import tkinter as tk
import sqlite3 as sq3
from tkinter import messagebox


#******************
#SQLiteに接続
#******************
dbname = "splpratice.db"

conn = sq3.connect(dbname)
c = conn.cursor()





def end_btn():
    conn.close()
    root.destroy()

if __name__ == "__main__":
    global root
    root = tk.Tk()
    root.title("Products master")
    root.geometry("400x300+200+200")
    msg_status = tk.Label(root, text="", relief=tk.SUNKEN)

    # ラベル
    l_code = tk.Label(text='ProductCode')   # ラベル名
    l_code.place(x=20, y=45)              # 表示位置 
    # テキストボックス
    t_code = tk.Entry(width=10)           # 幅３０
    t_code.place(x=110, y=45)             # 表示位置
    
    # ラベル
    l_c_code = tk.Label(text='ProductName')       # ラベル名
    l_c_code.place(x=20, y=70)               # 表示位置 
    # テキストボックス
    t_c_code = tk.Entry(width=35)            # 幅３０
    t_c_code.place(x=110, y=70)              # 表示位置

        # ラベル
    l_m_code = tk.Label(text='Price')       # ラベル名
    l_m_code.place(x=20, y=95)               # 表示位置 
    # テキストボックス
    t_m_code = tk.Entry(width=10)            # 幅３０
    t_m_code.place(x=110, y=95)              # 表示位置

        # ラベル
    l_ptitle1 = tk.Label(text='CategoryID')       # ラベル名
    l_ptitle1.place(x=20, y=120)               # 表示位置 
    # テキストボックス
    t_ptitle1 = tk.Entry(width=10)            # 幅３０
    t_ptitle1.place(x=110, y=120)              # 表示位置

# ----- ボタン ---------------------------

    # 登録更新ボタン
    btn = tk.Button(root, text='追加')
    btn.place(x=120, y=180) #表示位置

    # 検索ボタン
    btn = tk.Button(root, text='検索')
    btn.place(x=170, y=180) #表示位置

    # 終了ボタン
    btn = tk.Button(root, text='終了', command = end_btn)
    btn.place(x=220, y=180) #表示位置

    

    root.mainloop()
# -------------------------------------------------
